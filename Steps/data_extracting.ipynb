# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# The code defines a function called `extract_data_from_html` that takes a file path as input. This function reads an HTML file, uses BeautifulSoup for parsing, and extracts car-related data.
#
# It involves initializing a dictionary (car_data) to store data and a list `attributes_list` to track attributes. The function looks for a table with the class `driving-table` to extract car details like name, model, and price.
#
# It also identifies tables with the class `list_ads` to extract attribute-value pairs and updates the car_data dictionary.
#
# Finally, the function returns the populated car_data dictionary with the `extracted information`.

# %%
def extract_data_from_html(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        content = file.read()

    soup = BeautifulSoup(content, 'html.parser')

    car_data = {}

    attributes_list = []

    driving_table = soup.find('table', class_='driving-table')
    if driving_table:
        car_data['الأسم'] = driving_table.find('h3').text.strip()
        car_data['الموديل'] = driving_table.find('h5').text.strip().split()[-1]
        car_data['السعر'] = float(driving_table.find('h5', class_='post-price').text.split()[0])

    list_ads_tables = soup.find_all('table', class_='list_ads')

    for list_ads_table in list_ads_tables:
        for row in list_ads_table.find_all('tr'):
            td_elements = row.find_all('td')

            if len(td_elements) >= 2:
                attribute_td = td_elements[0]
                value_td = td_elements[1]

                attribute = attribute_td.text.strip()
                value = value_td.text.strip()

                attributes_list.append(attribute)

                car_data[attribute] = value 
                
    return car_data

# %% [markdown]
# Initialize an empty list to store data dictionaries
#
# Read all fiels contains (`.txt`) extension
#
# Call `extract_data_from_html` function, and send all data in `directory_path`

# %%
# Specify the directory path
directory_path = './data'

all_car_data = []

# Iterate through each file in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.txt'):
        file_path = os.path.join(directory_path, filename)
        car_data = extract_data_from_html(file_path)
        all_car_data.append(car_data)

# %% [markdown]
# Store all data as DataFrame using `Pandas library` and display sample of it.

# %%
# Create a DataFrame from the list of dictionaries
df = pd.DataFrame(all_car_data)

# Save the DataFrame to a CSV file
df.to_csv('car_data.csv', index=False)

# Display the DataFrame
df
# Out:
#              الأسم الموديل     السعر  لون السيارة نوع الوقود أصل السيارة  \
# 0      كيا اوبتيما    2014  100000.0    أبيض عاجي      بنزين       خصوصي
# 1              NaN     NaN       NaN          NaN        NaN         NaN
# 2              NaN     NaN       NaN          NaN        NaN         NaN
# 3      كيا سورينتو    2007   60000.0         سكني       ديزل       خصوصي
# 4    هونداي افانتي    2006   43500.0         سكني      بنزين       خصوصي
# 5              NaN     NaN       NaN          NaN        NaN         NaN
# 6         فيات 127    1982    5500.0          بيج      بنزين       خصوصي
# 7         بيجو 208    2014   54000.0          فضي      بنزين       خصوصي
# 8   بي ام دبليو x3    2015  205000.0         أسود       ديزل       خصوصي
# 9       اوبل كورسا    2015   65000.0       بترولي      بنزين       خصوصي
# 10     مرسيدس C200    2014  230000.0         أبيض      بنزين       خصوصي
# 11             NaN     NaN       NaN          NaN        NaN         NaN
# 12      فورد فيستا    2014   59000.0  أسود ميتالك      بنزين       خصوصي
# 13             NaN     NaN       NaN          NaN        NaN         NaN
# 14    نيسان باترول    2003   84000.0         أبيض      بنزين       خصوصي
# 15    فورد ترانزيت    2005   75000.0    أبيض عاجي       ديزل       خصوصي
# 16       بيجو 206+    2012   39000.0          فضي      بنزين       خصوصي
# 17     سكودا فابيا    2016   73000.0         أبيض      بنزين       خصوصي
#
#    رخصة السيارة      نوع الجير    الزجاج قوة الماتور عداد السيارة عدد الركاب  \
# 0      فلسطينية      اوتوماتيك  الكتروني        2000        75000        4+1
# 1           NaN            NaN       NaN         NaN          NaN        NaN
# 2           NaN            NaN       NaN         NaN          NaN        NaN
# 3      فلسطينية  نصف اوتوماتيك  الكتروني        2500       130000        7+1
# 4      فلسطينية      اوتوماتيك  الكتروني        1600          NaN        NaN
# 5           NaN            NaN       NaN         NaN          NaN        NaN
# 6      فلسطينية           عادي      يدوي         906         شغال        4+1
# 7      فلسطينية      اوتوماتيك  الكتروني        1200        38000        4+1
# 8      فلسطينية      اوتوماتيك  الكتروني        2000          NaN        5+1
# 9      فلسطينية           عادي  الكتروني        1400       ١٢٣٤٥٦        ٤+١
# 10     فلسطينية      اوتوماتيك  الكتروني        2000        50000        4+1
# 11          NaN            NaN       NaN         NaN          NaN        NaN
# 12     فلسطينية      اوتوماتيك  الكتروني        1600          NaN        NaN
# 13          NaN            NaN       NaN         NaN          NaN        NaN
# 14     فلسطينية           عادي  الكتروني        4500        56000          8
# 15     فلسطينية           عادي  الكتروني        2500       460000        7+1
# 16     فلسطينية           عادي  الكتروني        1400          NaN        4+1
# 17     فلسطينية      اوتوماتيك  الكتروني        1200        45000        4+1
#
#         وسيلة الدفع            معروضة أصحاب سابقون  \
# 0          نقدا فقط         للبيع فقط      يد اولى
# 1               NaN               NaN          NaN
# 2               NaN               NaN          NaN
# 3   إمكانية التقسيط  للبيع أو التبديل            2
# 4          نقدا فقط         للبيع فقط          NaN
# 5               NaN               NaN          NaN
# 6   إمكانية التقسيط         للبيع فقط           00
# 7          نقدا فقط         للبيع فقط          NaN
# 8          نقدا فقط         للبيع فقط            0
# 9   إمكانية التقسيط         للبيع فقط      يد اولى
# 10  إمكانية التقسيط         للبيع فقط            1
# 11              NaN               NaN          NaN
# 12         نقدا فقط         للبيع فقط          NaN
# 13              NaN               NaN          NaN
# 14  إمكانية التقسيط         للبيع فقط            0
# 15  إمكانية التقسيط  للبيع أو التبديل      يد اولى
# 16         نقدا فقط         للبيع فقط     يد ثانية
# 17         نقدا فقط         للبيع فقط            0
#
#                                                إضافات طرف ثالث  \
# 0   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nفتحة...     1340
# 1                                                 NaN      NaN
# 2                                                 NaN      NaN
# 3   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nفتحة...     1690
# 4   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nجنطا...     1340
# 5                                                 NaN      NaN
# 6                                     مُكيّف\nمسجل CD      467
# 7   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nجنطات مغنيسيو...     1035
# 8   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nفتحة...     1340
# 9   مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nجنطا...     1035
# 10  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nفتحة...     1340
# 11                                                NaN      NaN
# 12  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nوساد...     1340
# 13                                                NaN      NaN
# 14  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nجنطا...     1690
# 15  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nوساد...     1690
# 16  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nجنطا...     1035
# 17  مُكيّف\nإغلاق مركزي\nجهاز إنذار\nمسجل CD\nجنطا...     1035
#
#    التكميلي (جسم المركبة) المجموع
# 0                    1751    3090
# 1                     NaN     NaN
# 2                     NaN     NaN
# 3                    1050    2740
# 4                    1000    2340
# 5                     NaN     NaN
# 6                     500     967
# 7                    1000    2035
# 8                    3588    4928
# 9                    1138    2173
# 10                   4026    5365
# 11                    NaN     NaN
# 12                   1033    2373
# 13                    NaN     NaN
# 14                   1471    3160
# 15                   1313    3003
# 16                   1000    2035
# 17                   1278    2313
